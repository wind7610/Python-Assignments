# %% [markdown]
# # Task 1

# %% [markdown]
# # Q1 : Install Jupyter notebook and run the first program and share the screenshot of the output.

# %% [markdown]
# ![Scrennshot.jpg](attachment:Scrennshot.jpg)

# %% [markdown]
# # Q2 : Write a program which will find all such numbers which are divisible by 7 but are not a multipleof 5, between 2000 and 3200 (both included). The numbers obtained should be printed in a comma-separated sequence on a single line.

# %%
l = []
for x in range(2000,3201):
              if (x%7==0) and (x%5!=0):
                    l.append(str(x))
print(','.join(l))

# %% [markdown]
# # Q3 : Write a Python program to accept the users first and last name and then getting them printed in the the reverse order with a space between first name and last name.

# %%
firstname = input("Type first name : ")
lastname = input("Type last name : ")
print(lastname +" "+ firstname)
# Out:
# Type first name : Karthikeyan
# Type last name : Natarajan
# Natarajan Karthikeyan

# %% [markdown]
# # Q4 : Write a Python program to find the volume of a sphere with diameter 12cm.
# Formula: V=4/3 * π * r 3

# %%
pi=3.1415
r=12/2
V=4/3*pi*r**3
print(V)
# Out:
# 904.752

# %% [markdown]
# # Task 2

# %% [markdown]
# # Q1 : Write a program which accepts a sequence of comma-separated numbers from console and generate a list.

# %%
question = input("create comma seperated no's : ")
list = question.split(",")
print(list)
# Out:
# create comma seperated no's : 3,6,9,12,15,18,21,24,17,30
# ['3', '6', '9', '12', '15', '18', '21', '24', '17', '30']

# %% [markdown]
# # Q2 : Create the below pattern using nested for loop in Python.

# %%
n=5
for i in range(n):
    for j in range(i):
        print('*', end="")
    print('')
for i  in range(n,0,-1):
    for j in range(i):
        print('*', end="")
    print('')
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %% [markdown]
# # Q3 : Write a Python program to reverse a word after accepting the input from the user.

# %%
word = input("input a word to reverse : ")
for char in range(len(word) -1, -1, -1):
    print(word[char], end="")
# Out:
# input a word to reverse : Sachin Tendulkar
# rakludneT nihcaS

# %% [markdown]
# # Q4 : Write a Python Program to print the given string in the format specified in the sample output.

# %%
print("WE, THE PEOPLE OF INDIA,\n\thaving solemnly resolved to constitute India into a SOVEREIGN,! \n\t\tSOCIALIST,SECULAR,DEMOCRATIC REPUBLIC \n\t\tand to secure to all its citizens")
# Out:
# WE, THE PEOPLE OF INDIA,
# 	having solemnly resolved to constitute India into a SOVEREIGN,!
# 		SOCIALIST,SECULAR,DEMOCRATIC REPUBLIC
# 		and to secure to all its citizens
